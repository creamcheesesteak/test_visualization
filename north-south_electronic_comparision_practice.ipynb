# %% [markdown]
# <a href="https://colab.research.google.com/github/creamcheesesteak/test_visualization/blob/master/north-south_electronic_comparision_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_excel('남북한발전전력량.xlsx')
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  ...  2011  2012  2013  2014  2015  2016
# 0        남한     합계  1077  1186  1310  1444  ...  4969  5096  5171  5220  5281  5404
# 1       NaN     수력    64    51    49    60  ...    78    77    84    78    58    66
# 2       NaN     화력   484   573   696   803  ...  3343  3430  3581  3427  3402  3523
# 3       NaN    원자력   529   563   565   581  ...  1547  1503  1388  1564  1648  1620
# 4       NaN    신재생     -     -     -     -  ...     -    86   118   151   173   195
# 5        북한     합계   277   263   247   221  ...   211   215   221   216   190   239
# 6       NaN     수력   156   150   142   133  ...   132   135   139   130   100   128
# 7       NaN     화력   121   113   105    88  ...    79    80    82    86    90   111
# 8       NaN    원자력     -     -     -     -  ...     -     -     -     -     -     -
#
# [9 rows x 29 columns]

# %%
df = pd.read_excel('남북한발전전력량.xlsx')

# %%
df.iloc[[2,7],12:]
# Out:
#    2000  2001  2002  2003  2004  2005  ...  2011  2012  2013  2014  2015  2016
# 2  1518  1689  1821  1859  2056  2127  ...  3343  3430  3581  3427  3402  3523
# 7    92    96    84    79    81    84  ...    79    80    82    86    90   111
#
# [2 rows x 17 columns]

# %%
df_ns_f = df.iloc[[2,7],12:]

# %%
df_ns_f.index = ['South_f','North_f']

# %%
df_ns_f
# Out:
#          2000  2001  2002  2003  2004  2005  ...  2011  2012  2013  2014  2015  2016
# South_f  1518  1689  1821  1859  2056  2127  ...  3343  3430  3581  3427  3402  3523
# North_f    92    96    84    79    81    84  ...    79    80    82    86    90   111
#
# [2 rows x 17 columns]

# %%
df_ns_f.transpose()
# Out:
#      South_f North_f
# 2000    1518      92
# 2001    1689      96
# 2002    1821      84
# 2003    1859      79
# 2004    2056      81
# 2005    2127      84
# 2006    2272      99
# 2007    2551     103
# 2008    2658     114
# 2009    2802     110
# 2010    3196     103
# 2011    3343      79
# 2012    3430      80
# 2013    3581      82
# 2014    3427      86
# 2015    3402      90
# 2016    3523     111

# %%
df_ns_f = df_ns_f.transpose()

# %%
df_ns_f.plot()

# %%
df_ns_f.plot(kind='area')

# %%
df
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  ...  2011  2012  2013  2014  2015  2016
# 0        남한     합계  1077  1186  1310  1444  ...  4969  5096  5171  5220  5281  5404
# 1       NaN     수력    64    51    49    60  ...    78    77    84    78    58    66
# 2       NaN     화력   484   573   696   803  ...  3343  3430  3581  3427  3402  3523
# 3       NaN    원자력   529   563   565   581  ...  1547  1503  1388  1564  1648  1620
# 4       NaN    신재생     -     -     -     -  ...     -    86   118   151   173   195
# 5        북한     합계   277   263   247   221  ...   211   215   221   216   190   239
# 6       NaN     수력   156   150   142   133  ...   132   135   139   130   100   128
# 7       NaN     화력   121   113   105    88  ...    79    80    82    86    90   111
# 8       NaN    원자력     -     -     -     -  ...     -     -     -     -     -     -
#
# [9 rows x 29 columns]

# %%
df.iloc[[1,6],2:-2]
# Out:
#   1990 1991 1992 1993 1994 1995 1996  ... 2008 2009 2010 2011 2012 2013 2014
# 1   64   51   49   60   41   55   52  ...   56   56   65   78   77   84   78
# 6  156  150  142  133  138  142  125  ...  141  125  134  132  135  139  130
#
# [2 rows x 25 columns]

# %%
df_ns_w = df.iloc[[1,6],2:-2]

# %%
df_ns_w.index = ['South_w', 'North_w']

# %%
df_ns_w
# Out:
#         1990 1991 1992 1993 1994 1995 1996  ... 2008 2009 2010 2011 2012 2013 2014
# South_w   64   51   49   60   41   55   52  ...   56   56   65   78   77   84   78
# North_w  156  150  142  133  138  142  125  ...  141  125  134  132  135  139  130
#
# [2 rows x 25 columns]

# %%
df_ns_w.transpose()
# Out:
#      South_w North_w
# 1990      64     156
# 1991      51     150
# 1992      49     142
# 1993      60     133
# 1994      41     138
# 1995      55     142
# 1996      52     125
# 1997      54     107
# 1998      61     102
# 1999      61     103
# 2000      56     102
# 2001      42     106
# 2002      53     106
# 2003      69     117
# 2004      59     125
# 2005      52     131
# 2006      52     126
# 2007      50     133
# 2008      56     141
# 2009      56     125
# 2010      65     134
# 2011      78     132
# 2012      77     135
# 2013      84     139
# 2014      78     130

# %%
df_ns_w = df_ns_w.transpose()

# %%
df_ns_w.plot()

# %%
df_ns_w.plot(kind='bar')

# %%
df_ns_w.plot(kind='area')
